# %% [markdown]
# ## task_1

# %%
import pandas as pd
from aggreagtion import load_data
from aggreagtion import columns
from aggreagtion import mean
from aggreagtion import sum
from aggreagtion import univarate
from aggreagtion import correlation
from aggreagtion import PCA
from aggreagtion import median
from aggreagtion import per

# %%
df=load_data(path=r"C:\Users\ASUS VIVO\Desktop\data\Week2_challenge_data_source.xlsx")

# %%
df
# Out:
#                    Bearer Id               Start  Start ms  \
# 0       13114483460844900352 2019-04-04 12:01:18     770.0
# 1       13114483482878900224 2019-04-09 13:04:04     235.0
# 2       13114483484080500736 2019-04-09 17:42:11       1.0
# 3       13114483485442799616 2019-04-10 00:31:25     486.0
# 4       13114483499480700928 2019-04-12 20:10:23     565.0
# ...                      ...                 ...       ...
# 149996   7277825670196679680 2019-04-29 07:28:42     451.0
# 149997   7349883264234609664 2019-04-29 07:28:42     483.0
# 149998  13114483573367300096 2019-04-29 07:28:43     283.0
# 149999  13114483573367300096 2019-04-29 07:28:43     696.0
# 150000                                       NaT       NaN
#
#                        End  End ms  Dur. (ms)          IMSI  MSISDN/Number  \
# 0      2019-04-25 14:35:31   662.0  1823652.0  2.082014e+14   3.366496e+10
# 1      2019-04-25 08:15:48   606.0  1365104.0  2.082019e+14   3.368185e+10
# ...

# %% [markdown]
# Task 1.1 - Your employer wants to have an overview of the users’ behavior on those applications.
# Aggregate per user the following information in the column
# number of xDR sessions
# Session duration
# the total download (DL) and upload (UL) data
# the total data volume (in Bytes) during this session for each application

# %%
columns=columns(data=df)

# %% [markdown]
# Mean for each Bearer Id

# %%
mean(data=df,unique='Bearer Id')
# Out:
#                         Start ms      End ms      Dur. (ms)          IMSI  \
# Bearer Id
# 6917537518543529984   730.000000  593.000000   24534.000000  2.082015e+14
# 6917537604825860096   833.000000  699.000000   21489.000000  2.082014e+14
# 6917537608536819712   411.000000  385.000000   27786.000000  2.082018e+14
# 6917537633966310400   833.000000  486.000000   15635.000000  2.082014e+14
# 6917537638622189568     3.000000   89.000000   24264.000000  2.082022e+14
# ...                          ...         ...            ...           ...
# 13186541164985800704   72.000000  962.000000  145291.000000  2.082010e+14
# 13186541166737199104  986.000000  950.000000   86399.000000  2.082010e+14
# 13186541166776899584  368.000000  286.000000   86399.000000  2.082014e+14
# 13186541167134199808  211.000000  571.000000  103113.000000  2.082014e+14
#                       505.445455  514.693939   50779.983838  2.082016e+14
#
# ...

# %% [markdown]
# total_sum per Bearer Id

# %%
sum(data=df,unique='Bearer Id')
# Out:
#                         Start ms      End ms      Dur. (ms)          IMSI  \
# Bearer Id
# 6917537518543529984   730.000000  593.000000   24534.000000  2.082015e+14
# 6917537604825860096   833.000000  699.000000   21489.000000  2.082014e+14
# 6917537608536819712   411.000000  385.000000   27786.000000  2.082018e+14
# 6917537633966310400   833.000000  486.000000   15635.000000  2.082014e+14
# 6917537638622189568     3.000000   89.000000   24264.000000  2.082022e+14
# ...                          ...         ...            ...           ...
# 13186541164985800704   72.000000  962.000000  145291.000000  2.082010e+14
# 13186541166737199104  986.000000  950.000000   86399.000000  2.082010e+14
# 13186541166776899584  368.000000  286.000000   86399.000000  2.082014e+14
# 13186541167134199808  211.000000  571.000000  103113.000000  2.082014e+14
#                       505.445455  514.693939   50779.983838  2.082016e+14
#
# ...

# %%
median(data=df,unique='Bearer Id')
# Out:
#                       Start ms  End ms  Dur. (ms)          IMSI  \
# Bearer Id
# 6917537518543529984      730.0   593.0    24534.0  2.082015e+14
# 6917537604825860096      833.0   699.0    21489.0  2.082014e+14
# 6917537608536819712      411.0   385.0    27786.0  2.082018e+14
# 6917537633966310400      833.0   486.0    15635.0  2.082014e+14
# 6917537638622189568        3.0    89.0    24264.0  2.082022e+14
# ...                        ...     ...        ...           ...
# 13186541164985800704      72.0   962.0   145291.0  2.082010e+14
# 13186541166737199104     986.0   950.0    86399.0  2.082010e+14
# 13186541166776899584     368.0   286.0    86399.0  2.082014e+14
# 13186541167134199808     211.0   571.0   103113.0  2.082014e+14
#                          498.0   514.5    32258.0  2.082015e+14
#
#                       MSISDN/Number          IMEI  Avg RTT DL (ms)  \
# Bearer Id
# 6917537518543529984    3.360865e+10  8.675720e+13            429.0
# ...

# %%
correlation(data=df)
# Out:
#                                           Start ms    End ms  Dur. (ms)  \
# Start ms                                  1.000000  0.120945   0.001287
# End ms                                    0.120945  1.000000  -0.001302
# Dur. (ms)                                 0.001287 -0.001302   1.000000
# IMSI                                     -0.000054  0.000328  -0.019798
# MSISDN/Number                            -0.001021 -0.001890   0.024616
# IMEI                                     -0.001133 -0.000032  -0.058043
# Avg RTT DL (ms)                           0.004141 -0.005287  -0.052472
# Avg RTT UL (ms)                          -0.002221 -0.002607  -0.002981
# Avg Bearer TP DL (kbps)                  -0.000690  0.000694  -0.165355
# Avg Bearer TP UL (kbps)                  -0.001268  0.000687  -0.113996
# TCP DL Retrans. Vol (Bytes)               0.000328  0.004941   0.018902
# TCP UL Retrans. Vol (Bytes)              -0.003581 -0.003375   0.006496
# ...

# %%
univarate(data=df)

# %% [markdown]
# Task 2.1 - Following the above, perform the following tasks:
# Aggregate the above metrics per customer id (MSISDN) and report the top 10 customers per engagement metric
# Normalize each engagement metric and run a k-means (k=3) to classify customers in three groups of engagement.
# Compute the minimum, maximum, average & total non-normalized metrics for each cluster. Interpret your results visually with accompanying text explaining your findings.
# Aggregate user total traffic per application and derive the top 10 most engaged users per application
# Plot the top 3 most used applications using appropriate charts.

# %%
sum(data=df,unique='MSISDN/Number')
# Out:
#                Start ms  End ms  Dur. (ms)          IMSI  MSISDN/Number  \
# MSISDN/Number
# 3.360100e+10      138.0   278.0   116720.0  2.082014e+14   3.360100e+10
# 3.360100e+10      422.0   385.0   181230.0  2.082015e+14   3.360100e+10
# 3.360100e+10       80.0   454.0   134969.0  2.082019e+14   3.360100e+10
# 3.360101e+10      158.0   182.0    49878.0  2.082017e+14   3.360101e+10
# 3.360101e+10      648.5   875.0    18552.0  2.082015e+14   3.360101e+10
# ...                 ...     ...        ...           ...            ...
# 3.379000e+10      829.0   517.0     8810.0  2.082014e+14   3.379000e+10
# 3.379000e+10      846.0   505.0   140988.0  2.082010e+14   3.379000e+10
# 3.197021e+12      345.0   670.0   877385.0  2.040808e+14   3.197021e+12
# 3.370000e+14      811.0    12.0   253030.0  2.082095e+14   3.370000e+14
# 8.823971e+14      259.0   459.0   869844.0  2.040471e+14   8.823971e+14
#
#                        IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# MSISDN/Number
# ...
